# %%
#imports
import sys
sys.path.append('/home/harry/personal/uni/project/individual/harry/model')
from model import *

params = {
        'learning_rate': 0.001,
        'batch_size': 32,
        'seq_length': 7,
        'transformer_encoder_layer_params': {
            'd_model': 64,
            'nhead': 4,
            'dim_feedforward': 256,
            'dropout': 0.1,
            'activation': 'relu'
        },
        'transformer_layer_params': {
            'num_layers': 2,
        },
        'dataset': '2016-2019',
        'train_test_split': 'prior:2019',
        'features': ['sum_30_min_demand', 'avg_temp'],
        'visualise': True
    }

train_model(params)
# Out:
# Using device: cuda
#
# Train Set Metrics:
# MSE: 281505553.8864
# MAE: 11961.9951
# RMSE: 16778.1272
# MAPE: 3.0974
#
# Test Set Metrics:
# MSE: 414889552.1375
# MAE: 15014.1270
# RMSE: 20368.8378
# MAPE: 3.9317
# np.float64(3.93167073051877)
