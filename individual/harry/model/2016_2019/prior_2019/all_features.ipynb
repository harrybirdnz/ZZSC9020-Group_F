# %%
#imports
import sys
sys.path.append('/home/harry/personal/uni/project/individual/harry/model')

from model import *

feature_names = [
    'is_summer', 'is_autumn', 'is_winter', 'is_spring',
    'is_monday', 'is_tuesday', 'is_wednesday', 'is_thursday', 'is_friday', 'is_saturday', 'is_sunday',
    'is_weekday', 'is_weekend',
    'is_jan', 'is_feb', 'is_mar', 'is_apr', 'is_may', 'is_jun', 'is_jul', 'is_aug', 'is_sep', 'is_oct', 'is_nov', 'is_dec',
    'min_30_min_demand',
    'avg_30_min_demand',
    'max_30_min_demand',
    'avg_temp',
    'max_temp',
    'min_temp',
    'hd_next_24h',
    'cd_next_24h'
]

# %%
params = {
    'learning_rate': 0.00023012066138871276,
    'batch_size': 47,
    'seq_length': 14,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 355,
        'dropout': 0.043975107811000946,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 1,
    },
    'dataset': '2016-2019',
    'train_test_split': 'prior:2019',
    'features': ['sum_30_min_demand'] + feature_names,
    'num_epochs': num_epochs,
    'patience': patience,
    'visualise': True
}

result_model = median_model(params, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#       1 params = {
#       2     'learning_rate': 0.00023012066138871276,
#       3     'batch_size': 47,
#       4     'seq_length': 14,
#       5     'transformer_encoder_layer_params': {
#       6         'd_model': 64,
#       7         'nhead': 4,
#       8         'dim_feedforward': 355,
#       9         'dropout': 0.043975107811000946,
#      10         'activation': 'relu'
#      11     },
#      12     'transformer_layer_params': {
#      13         'num_layers': 1,
#      14     },
#      15     'dataset': '2016-2019',
#      16     'train_test_split': 'prior:2019',
# ---> 17     'features': ['sum_30_min_demand'] + feature_names,
#      18     'num_epochs': num_epochs,
#      19     'patience': patience,
#      20     'visualise': True
#      21 }
#      23 result_model = median_model(params, 5)
#
# NameError: name 'feature_names' is not defined

# %%
params = {
    'learning_rate': 0.00023012066138871276,
    'batch_size': 47,
    'seq_length': 14,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 355,
        'dropout': 0.043975107811000946,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 1,
    },
    'dataset': '2016-2019',
    'train_test_split': 'prior:2019',
    'features': ['sum_30_min_demand'] + feature_names,
    'num_epochs': num_epochs,
    'patience': patience,
    'visualise': True
}

result_model = median_model(params, 20)
# Out:
# Median Model Results after 20 runs:
#
# Train Set Metrics:
# MSE: 117597762.1914
# MAE: 7803.0741
# RMSE: 10844.2502
# MAPE: 2.0324
#
# Test Set Metrics:
# MSE: 270064644.9680
# MAE: 11321.9289
# RMSE: 16433.6437
# MAPE: 2.9140
