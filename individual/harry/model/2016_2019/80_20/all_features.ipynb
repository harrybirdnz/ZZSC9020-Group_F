# %%
#imports
import sys
sys.path.append('/home/harry/personal/uni/project/individual/harry/model')

from model import *

feature_names = [
    'is_summer', 'is_autumn', 'is_winter', 'is_spring',
    'is_monday', 'is_tuesday', 'is_wednesday', 'is_thursday', 'is_friday', 'is_saturday', 'is_sunday',
    'is_weekday', 'is_weekend',
    'is_jan', 'is_feb', 'is_mar', 'is_apr', 'is_may', 'is_jun', 'is_jul', 'is_aug', 'is_sep', 'is_oct', 'is_nov', 'is_dec',
    'min_30_min_demand',
    'avg_30_min_demand',
    'max_30_min_demand',
    'avg_temp',
    'max_temp',
    'min_temp',
    'hd_next_24h',
    'cd_next_24h'
]

# %%
params = {
    'learning_rate': 0.001,
    'batch_size': 32,
    'seq_length': 7,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 256,
        'dropout': 0.1,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 2,
    },
    'dataset': '2016-2019',
    'train_test_split': '80:20',
    'features': ['sum_30_min_demand'] + feature_names,
    'num_epochs': num_epochs,
    'patience': patience,
    'visualise': True
}

train_model(params)
# Out:
# Using device: cuda
#
# Train Set Metrics:
# MSE: 38666382.2366
# MAE: 4613.0765
# RMSE: 6218.2298
# MAPE: 1.1958
#
# Test Set Metrics:
# MSE: 181556103.2149
# MAE: 9909.1818
# RMSE: 13474.2756
# MAPE: 2.6827
# np.float64(2.682657022551229)

# %%
params = {
    'learning_rate': 0.0066779511652954255,
    'batch_size': 28,
    'seq_length': 7,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 355,
        'dropout': 0.07519874608589755,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 1,
    },
    'dataset': '2016-2019',
    'train_test_split': '80:20',
    'features': ['sum_30_min_demand'] + feature_names,
    'num_epochs': num_epochs,
    'patience': patience,
    'visualise': True
}

median_model(params, 5)
# Out:
# Median Model Results after 5 runs:
#
# Train Set Metrics:
# MSE: 77656975.6728
# MAE: 6435.8169
# RMSE: 8812.3195
# MAPE: 1.6543
#
# Test Set Metrics:
# MSE: 157784042.9549
# MAE: 9524.1066
# RMSE: 12561.2118
# MAPE: 2.5697
# np.float64(2.569681953814372)

# %%
params = {
    'learning_rate': 0.0002882851523818458,
    'batch_size': 29,
    'seq_length': 10,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 164,
        'dropout': 0.07670173154434252,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 2,
    },
    'dataset': '2016-2019',
    'train_test_split': '80:20',
    'features': ['sum_30_min_demand'] + feature_names,
    'num_epochs': num_epochs,
    'patience': patience,
    'visualise': True
}

median_model(params, 5)
# Out:
# Median Model Results after 5 runs:
#
# Train Set Metrics:
# MSE: 66054994.0088
# MAE: 6002.0937
# RMSE: 8127.4223
# MAPE: 1.5610
#
# Test Set Metrics:
# MSE: 161683398.0913
# MAE: 9459.5590
# RMSE: 12715.4787
# MAPE: 2.5496
# np.float64(2.54959437493734)
