# %%
#imports
import sys
sys.path.append('/home/harry/personal/uni/project/individual/harry/model')
from model import *

# %%
params = {
        'learning_rate': 0.001,
        'batch_size': 32,
        'seq_length': 7,
        'transformer_encoder_layer_params': {
            'd_model': 64,
            'nhead': 4,
            'dim_feedforward': 256,
            'dropout': 0.1,
            'activation': 'relu'
        },
        'transformer_layer_params': {
            'num_layers': 2,
        },
        'dataset': '2010-2019',
        'train_test_split': 'prior:2019',
        'features': ['sum_30_min_demand', 'avg_temp'],
        'visualise': True,
    }

train_model(params)
# Out:
# Using device: cuda
#
# Train Set Metrics:
# MSE: 205335348.7662
# MAE: 9908.0970
# RMSE: 14329.5272
# MAPE: 2.5276
#
# Test Set Metrics:
# MSE: 400532140.4780
# MAE: 14606.4307
# RMSE: 20013.2991
# MAPE: 3.8019
# np.float64(3.8019088490051742)

# %%
params = {
        'learning_rate': 0.001,
        'batch_size': 32,
        'seq_length': 7,
        'transformer_encoder_layer_params': {
            'd_model': 64,
            'nhead': 4,
            'dim_feedforward': 256,
            'dropout': 0.1,
            'activation': 'relu'
        },
        'transformer_layer_params': {
            'num_layers': 2,
        },
        'dataset': '2010-2019',
        'train_test_split': 'prior:2019',
        'features': ['sum_30_min_demand', 'avg_temp'],
        'visualise': True,
    }

median_model(params, 5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#       1 params = {
#       2         'learning_rate': 0.001,
#       3         'batch_size': 32,
#    (...)
#      18         'visualise': True,
#      19     }
# ---> 21 median_mape(params)
#
# File ~/personal/uni/project/individual/harry/model/model.py:284, in median_mape(params)
#     282 # sd of 0.08 on 100 runs, therefore average over 5 runs to reduce variance to ~0.04
#     283 for i in range(5):  # Average over 5 runs to reduce variance
# --> 284     mape, results = train_model(params)
#     285     mapes.append(mape)
#     286     results_list.append(results)
#
# File ~/personal/uni/project/individual/harry/model/model.py:272, in train_model(params)
#     270 sequences, targets, datetimes, scaler_X = prepare_data(params)
#     271 # Get train/test splits from train_transformer_model
# --> 272 model, train_losses, val_losses, X_train, y_train, X_test, y_test = train_transformer_model(
#     273     sequences, targets, input_dim, datetimes, params
#     274 )
#     275 mape, results = postprocess(model, X_train, y_train, X_test, y_test, scaler_X, train_losses, val_losses, params, params['visualise'])
#     276 return mape, results
#
# File ~/personal/uni/project/individual/harry/model/model.py:178, in train_transformer_model(sequences, targets, input_dim, datetimes, params)
#     176 predictions = model(batch_X)
#     177 loss = criterion(predictions, batch_y)
# --> 178 loss.backward()
#     179 optimizer.step()
#     180 train_loss += loss.item() * batch_X.size(0)
#
# File ~/personal/uni/project/.venv/lib/python3.10/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~/personal/uni/project/.venv/lib/python3.10/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/personal/uni/project/.venv/lib/python3.10/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:
