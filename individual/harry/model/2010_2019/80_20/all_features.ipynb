# %%
#imports
import sys
sys.path.append('/home/harry/personal/uni/project/individual/harry/model')
from model import *

feature_names = [
    'is_summer', 'is_autumn', 'is_winter', 'is_spring',
    'is_monday', 'is_tuesday', 'is_wednesday', 'is_thursday', 'is_friday', 'is_saturday', 'is_sunday',
    'is_weekday', 'is_weekend',
    'is_jan', 'is_feb', 'is_mar', 'is_apr', 'is_may', 'is_jun', 'is_jul', 'is_aug', 'is_sep', 'is_oct', 'is_nov', 'is_dec',
    'min_30_min_demand',
    'avg_30_min_demand',
    'max_30_min_demand',
    'avg_temp',
    'max_temp',
    'min_temp',
    'hd_next_24h',
    'cd_next_24h'
]

# %%
params = {
    'learning_rate': 0.0001072442321989738,
    'batch_size': 64,
    'seq_length': 21,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 369,
        'dropout': 0.0458412282962931,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 1,
    },
    'dataset': '2010-2019',
    'train_test_split': 'prior:2019',
    'features': ['sum_30_min_demand'] + feature_names,
    'visualise': True,
}

result_model = median_model(params, 10)
# Out:
# Median Model Results after 10 runs:
#
# Train Set Metrics:
# MSE: 111068367.1000
# MAE: 7443.0214
# RMSE: 10538.8978
# MAPE: 1.9051
#
# Test Set Metrics:
# MSE: 206451967.3004
# MAE: 10618.2499
# RMSE: 14368.4365
# MAPE: 2.7615

# %%
params = {
    'learning_rate': 0.0001455007331587193,
    'batch_size': 50,
    'seq_length': 18,
    'transformer_encoder_layer_params': {
        'd_model': 64,
        'nhead': 4,
        'dim_feedforward': 250,
        'dropout': 0.036070918789856035,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 1,
    },
    'dataset': '2010-2019',
    'train_test_split': 'prior:2019',
    'features': ['sum_30_min_demand'] + feature_names,
    'visualise': True,
}

result_model = median_model(params, 5)
# Out:
# Median Model Results after 5 runs:
#
# Train Set Metrics:
# MSE: 120996593.7642
# MAE: 7767.4970
# RMSE: 10999.8452
# MAPE: 1.9868
#
# Test Set Metrics:
# MSE: 224026165.3024
# MAE: 10692.9694
# RMSE: 14967.5036
# MAPE: 2.7787

# %%
# optuna best
params = {
    'learning_rate': 0.00010837405552052769,
    'batch_size': 49,
    'seq_length': 11,
    'transformer_encoder_layer_params': {
        'd_model': 48,
        'nhead': 6,
        'dim_feedforward': 463,
        'dropout': 0.059466553772069955,
        'activation': 'relu'
    },
    'transformer_layer_params': {
        'num_layers': 2,
    },
    'dataset': '2010-2019',
    'train_test_split': 'prior:2019',
    'features': ['sum_30_min_demand'] + feature_names,
    'visualise': True,
}

result_model = median_model(params, 5)
# Out:
# Median Model Results after 5 runs:
#
# Train Set Metrics:
# MSE: 112315929.8454
# MAE: 7460.3622
# RMSE: 10597.9210
# MAPE: 1.9020
#
# Test Set Metrics:
# MSE: 230706974.9810
# MAE: 10798.0489
# RMSE: 15189.0413
# MAPE: 2.7810

# %%
result_model
explain_transformer_feature_importance(result_model['model'], result_model['X_train'], result_model['X_test'], params)
# Out:
# Using 3276 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/365 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[19], line 2
#       1 result_model
# ----> 2 explain_transformer_feature_importance(result_model['model'], result_model['X_train'], result_model['X_test'], params)
#
# File ~/personal/uni/project/individual/harry/model/model.py:381, in explain_transformer_feature_importance(model, X_train, X_test, params)
#     379 # SHAP KernelExplainer
#     380 explainer = shap.KernelExplainer(predict_fn, background)
# --> 381 shap_values = explainer.shap_values(X_explain, nsamples=100)
#     383 # Reshape SHAP values to (samples, seq_length, features)
# ...
