# %%
#imports
import sys
sys.path.append('/home/harry/personal/uni/project/individual/harry/model')
from model import *


params = {
        'learning_rate': 0.001,
        'batch_size': 32,
        'seq_length': 7,
        'transformer_encoder_layer_params': {
            'd_model': 64,
            'nhead': 4,
            'dim_feedforward': 256,
            'dropout': 0.1,
            'activation': 'relu'
        },
        'transformer_layer_params': {
            'num_layers': 2,
        },
        'dataset': '2010-2019',
        'train_test_split': '80:20',
        'features': ['sum_30_min_demand', 'avg_temp'],
        'visualise': True
    }

train_model(params)
# Out:
# Using device: cuda
#
# Train Set Metrics:
# MSE: 240589046.7216
# MAE: 10725.3443
# RMSE: 15510.9331
# MAPE: 2.7349
#
# Test Set Metrics:
# MSE: 361953704.0128
# MAE: 13734.8955
# RMSE: 19025.0809
# MAPE: 3.5650
# np.float64(3.565048913500856)
