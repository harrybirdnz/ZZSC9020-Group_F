# %%
#imports
from model import *

params = {
        'learning_rate': 0.001,
        'batch_size': 32,
        'seq_length': 7,
        'transformer_encoder_layer_params': {
            'd_model': 64,
            'nhead': 4,
            'dim_feedforward': 256,
            'dropout': 0.1,
            'activation': 'relu'
        },
        'transformer_layer_params': {
            'num_layers': 2,
        },
        'dataset': '2010-2019',
        'train_test_split': '80:20'
    }

sequences, targets, datetimes, scaler_X = prepare_data(params)


model, train_losses, val_losses = train_transformer_model(
    sequences.numpy(), targets.numpy(), input_dim, datetimes, params
)

postprocess(model, sequences, targets, scaler_X, train_losses, val_losses)



print("Training completed and model saved!")
# Out:
# Using device: cuda
#
# Final Metrics:
# MSE: 231968779.7211
# MAE: 10511.6712
# RMSE: 15230.5213
# MAPE: 2.6949
# Training completed and model saved!
