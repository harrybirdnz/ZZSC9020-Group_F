# %% [markdown]
# <a href="https://colab.research.google.com/github/harrybirdnz/ZZSC9020/blob/main/Group_Project_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the ZZSC9020 project repository from GitHub
# !git clone https://github.com/UNSW-ZZSC9020/project.git
# Out:
# Cloning into 'project'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 80 (delta 15), reused 12 (delta 12), pack-reused 57 (from 2)
# Receiving objects: 100% (80/80), 197.08 MiB | 21.08 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !mkdir -p data

# %%
# !cat project/data/NSW/forecastdemand_nsw.csv.zip.part* > data/forecastdemand_nsw.csv.zip

# %%
# !unzip data/forecastdemand_nsw.csv.zip -d data
# !unzip project/data/NSW/temperature_nsw.csv.zip -d data
# Out:
# Archive:  data/forecastdemand_nsw.csv.zip
#   inflating: data/forecastdemand_nsw.csv
# Archive:  project/data/NSW/temperature_nsw.csv.zip
#   inflating: data/temperature_nsw.csv
# unzip:  cannot find or open project/data/NSW/weather_nsw.csv.zip, project/data/NSW/weather_nsw.csv.zip.zip or project/data/NSW/weather_nsw.csv.zip.ZIP.

# %%
# !unzip project/data/NSW/totaldemand_nsw.csv.zip -d data
# Out:
# Archive:  project/data/NSW/totaldemand_nsw.csv.zip
#   inflating: data/totaldemand_nsw.csv

# %%
# !rm data/forecastdemand_nsw.csv.zip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
forecastDF = pd.read_csv('data/forecastdemand_nsw.csv')
forecastDF.head()
# Out:
#    PREDISPATCHSEQNO REGIONID  PERIODID  FORECASTDEMAND          LASTCHANGED  \
# 0        2009123018     NSW1        71         7832.04  2009-12-30 12:31:49
# 1        2009123019     NSW1        70         7832.04  2009-12-30 13:01:43
# 2        2009123020     NSW1        69         7832.03  2009-12-30 13:31:36
# 3        2009123021     NSW1        68         7832.03  2009-12-30 14:01:44
# 4        2009123022     NSW1        67         7830.96  2009-12-30 14:31:35
#
#               DATETIME
# 0  2010-01-01 00:00:00
# 1  2010-01-01 00:00:00
# 2  2010-01-01 00:00:00
# 3  2010-01-01 00:00:00
# 4  2010-01-01 00:00:00

# %%
temperatureDF = pd.read_csv('data/temperature_nsw.csv')
temperatureDF.head()
# Out:
#     LOCATION       DATETIME  TEMPERATURE
# 0  Bankstown  1/1/2010 0:00         23.1
# 1  Bankstown  1/1/2010 0:01         23.1
# 2  Bankstown  1/1/2010 0:30         22.9
# 3  Bankstown  1/1/2010 0:50         22.7
# 4  Bankstown  1/1/2010 1:00         22.6

# %%
demandDF = pd.read_csv('data/totaldemand_nsw.csv')
demandDF.head()
# Out:
#         DATETIME  TOTALDEMAND REGIONID
# 0  1/1/2010 0:00      8038.00     NSW1
# 1  1/1/2010 0:30      7809.31     NSW1
# 2  1/1/2010 1:00      7483.69     NSW1
# 3  1/1/2010 1:30      7117.23     NSW1
# 4  1/1/2010 2:00      6812.03     NSW1

# %%
demandDF['DATETIME'] = demandDF['DATETIME'].astype('datetime64[ns]')
demandDF.head()
# Out:
#              DATETIME  TOTALDEMAND REGIONID
# 0 2010-01-01 00:00:00      8038.00     NSW1
# 1 2010-01-01 00:30:00      7809.31     NSW1
# 2 2010-01-01 01:00:00      7483.69     NSW1
# 3 2010-01-01 01:30:00      7117.23     NSW1
# 4 2010-01-01 02:00:00      6812.03     NSW1

# %%
temperatureDF['DATETIME'] = temperatureDF['DATETIME'].astype('datetime64[ns]')
temperatureDF.head()
# Out:
#     LOCATION            DATETIME  TEMPERATURE
# 0  Bankstown 2010-01-01 00:00:00         23.1
# 1  Bankstown 2010-01-01 00:01:00         23.1
# 2  Bankstown 2010-01-01 00:30:00         22.9
# 3  Bankstown 2010-01-01 00:50:00         22.7
# 4  Bankstown 2010-01-01 01:00:00         22.6
